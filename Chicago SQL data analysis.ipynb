# %% [markdown]
# # Chicago crimes data Analysis With SQL
#
# #### First we need to install necessary libraries, and load the SQL extension.

# %%
# !pip install ipython-sql
# !pip install ibm-db-sa
# !pip install sqlalchemy==1.3.9
# %load_ext sql
# Out:
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# ...
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/dhcrypto.py:16: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/secretstorage/util.py:25: CryptographyDeprecationWarning: int_from_bytes is deprecated, use int.from_bytes instead
#   from cryptography.utils import int_from_bytes
# ...

# %% [markdown]
# #### In the next cell we connect to the IBM DB2 database that I have already loaded with the necessary data for this project.
#
# Code will be hidden due to sensitive nature of credentials

# %%
# The code was removed by Watson Studio for sharing.

# %% [markdown]
# ### SQL Analysis of data
#
#
#
# ##### Find the total number of crimes recorded in the CRIME table.

# %%
# %sql SELECT COUNT(Id) FROM CHICAGO_CRIME_DATA;
# Out:
#  * ibm_db_sa://shf82721:***@dashdb-txn-sbox-yp-dal09-11.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('533'),)]

# %% [markdown]
# ##### List community areas with per capita income less than 11000.

# %%
# %sql Select COMMUNITY_AREA_NUMBER, COMMUNITY_AREA_NAME, PER_CAPITA_INCOME from CENSUS_DATA where PER_CAPITA_INCOME < 11000;
# Out:
#  * ibm_db_sa://shf82721:***@dashdb-txn-sbox-yp-dal09-11.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(26, 'West Garfield Park', 10934),
#  (30, 'South Lawndale', 10402),
#  (37, 'Fuller Park', 10432),
#  (54, 'Riverdale', 8201)]

# %% [markdown]
# ##### List all case numbers for crimes  involving minors

# %%
# %sql select CASE_NUMBER, DESCRIPTION from CHICAGO_CRIME_DATA where DESCRIPTION like '%MINOR%';
# Out:
#  * ibm_db_sa://shf82721:***@dashdb-txn-sbox-yp-dal09-11.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('HL266884', 'SELL/GIVE/DEL LIQUOR TO MINOR'),
#  ('HK238408', 'ILLEGAL CONSUMPTION BY MINOR')]

# %% [markdown]
# ##### List all kidnapping crimes involving a child

# %%
# %sql select CASE_NUMBER, PRIMARY_TYPE, DESCRIPTION from CHICAGO_CRIME_DATA where PRIMARY_TYPE like '%KIDNAP%' and DESCRIPTION like '%CHILD%';
# Out:
#  * ibm_db_sa://shf82721:***@dashdb-txn-sbox-yp-dal09-11.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('HN144152', 'KIDNAPPING', 'CHILD ABDUCTION/STRANGER')]

# %% [markdown]
# ##### What kinds of crimes were recorded at schools?

# %%
# %sql select primary_type, description, location_description from CHICAGO_CRIME_DATA where location_description like '%SCHOOL%'
# Out:
#  * ibm_db_sa://shf82721:***@dashdb-txn-sbox-yp-dal09-11.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('BATTERY', 'SIMPLE', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('BATTERY', 'PRO EMP HANDS NO/MIN INJURY', 'SCHOOL, PUBLIC, BUILDING'),
#  ('BATTERY', 'SIMPLE', 'SCHOOL, PUBLIC, BUILDING'),
#  ('BATTERY', 'SIMPLE', 'SCHOOL, PUBLIC, BUILDING'),
#  ('BATTERY', 'SIMPLE', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('CRIMINAL DAMAGE', 'TO VEHICLE', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('NARCOTICS', 'POSS: HEROIN(WHITE)', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('NARCOTICS', 'MANU/DEL:CANNABIS 10GM OR LESS', 'SCHOOL, PUBLIC, BUILDING'),
#  ('ASSAULT', 'PRO EMP HANDS NO/MIN INJURY', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('CRIMINAL TRESPASS', 'TO LAND', 'SCHOOL, PUBLIC, GROUNDS'),
#  ('PUBLIC PEACE VIOLATION', 'BOMB THREAT', 'SCHOOL, PRIVATE, BUILDING'),
#  ('PUBLIC PEACE VIOLATION', 'BOMB THREAT', 'SCHOOL, PUBLIC, BUILDING')]

# %% [markdown]
# ##### List the average safety score for all types of schools.

# %%
# %sql select AVG(safety_score) as average_safety_score from chicago_public_schools
# Out:
#  * ibm_db_sa://shf82721:***@dashdb-txn-sbox-yp-dal09-11.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(Decimal('49.504873'),)]

# %% [markdown]
# ##### List 5 community areas with highest % of households below poverty line

# %%
# %sql select community_area_name, percent_households_below_poverty from census_data order by percent_households_below_poverty desc limit 5
# Out:
#  * ibm_db_sa://shf82721:***@dashdb-txn-sbox-yp-dal09-11.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('Riverdale', Decimal('56.5')),
#  ('Fuller Park', Decimal('51.2')),
#  ('Englewood', Decimal('46.6')),
#  ('North Lawndale', Decimal('43.1')),
#  ('East Garfield Park', Decimal('42.4'))]

# %% [markdown]
# ##### Which community area is most crime prone?

# %%
# %sql select DISTRICT, count(*) as total_crimes_in_district from chicago_crime_data group by district order by total_crimes_in_district desc limit 1
# Out:
#  * ibm_db_sa://shf82721:***@dashdb-txn-sbox-yp-dal09-11.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(11, Decimal('48'))]

# %% [markdown]
# ##### Use a sub-query to find the name of the community area with highest hardship index

# %%
# %sql select community_area_name, hardship_index from census_data where hardship_index = (select max(hardship_index) from census_data);
# Out:
#  * ibm_db_sa://shf82721:***@dashdb-txn-sbox-yp-dal09-11.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('Riverdale', 98)]

# %% [markdown]
# ##### Determine the Community Area Name with most number of crimes

# %%
# %sql select community_area_number, count(*) as number_of_crimes from chicago_crime_data group by community_area_number order by number_of_crimes desc limit 1
# Out:
#  * ibm_db_sa://shf82721:***@dashdb-txn-sbox-yp-dal09-11.services.dal.bluemix.net:50000/BLUDB
# Done.
# [(25, Decimal('43'))]

# %%
# %sql select community_area_name, community_area_number from census_data where community_area_number=25
# Out:
#  * ibm_db_sa://shf82721:***@dashdb-txn-sbox-yp-dal09-11.services.dal.bluemix.net:50000/BLUDB
# Done.
# [('Austin', 25)]
